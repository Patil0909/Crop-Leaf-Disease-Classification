# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img_path = r"E:\DATA\PlantVillage\Tomato_healthy\0a0d6a11-ddd6-4dac-8469-d5f65af5afca___RS_HL 0555.JPG"

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.axis("off")
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
img_resized = cv2.resize(img, (128, 128))

img_array = np.array(img_resized, dtype=np.float32) / 255.0

img_flat = img_array.reshape(1, -1)

prediction = rf.predict(img_flat)

predicted_class = class_names[prediction[0]]

print("Predicted Disease:", predicted_class)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       3 img_array = np.array(img_resized, dtype=np.float32) / 255.0
#       4
#       5 img_flat = img_array.reshape(1, -1)
#       6
# ----> 7 prediction = rf.predict(img_flat)
#       8
#       9 predicted_class = class_names[prediction[0]]
#      10
#
# NameError: name 'rf' is not defined

# %%
from sklearn.ensemble import RandomForestClassifier

X_train_flat = X_train.reshape(X_train.shape[0], -1)
X_test_flat = X_test.reshape(X_test.shape[0], -1)

rf = RandomForestClassifier(
    n_estimators=100,
    random_state=42,
    n_jobs=-1
)

rf.fit(X_train_flat, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 from sklearn.ensemble import RandomForestClassifier
#       2
# ----> 3 X_train_flat = X_train.reshape(X_train.shape[0], -1)
#       4 X_test_flat = X_test.reshape(X_test.shape[0], -1)
#       5
#       6 rf = RandomForestClassifier(
#
# NameError: name 'X_train' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 from sklearn.ensemble import RandomForestClassifier
#       2
# ----> 3 X_train_flat = X_train.reshape(X_train.shape[0], -1)
#       4 X_test_flat = X_test.reshape(X_test.shape[0], -1)
#       5
#       6 rf = RandomForestClassifier(
#
# NameError: name 'X_train' is not defined
